# %%
import pandas as pd
print('pandas:', pd.__version__)
import numpy as np
print('numpy:', np.__version__)

import matplotlib.pyplot as plt
import matplotlib as mpl
print('matplotlib:', mpl.__version__)
import seaborn as sns
print('seaborn:', sns.__version__)

# matplotlib settings
from cycler import cycler # to change color order
# %matplotlib inline
plt.style.use('seaborn-ticks')
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['xtick.labelsize'], plt.rcParams['ytick.labelsize']  = 11, 11
# plt.rcParams['axes.prop_cycle'] = cycler(color=['r', 'g', 'b', 'y'])
# mpl.rc('font', family='Verdana') # for Russian
# Out:
# pandas: 1.0.2
# numpy: 1.18.1
# matplotlib: 3.1.3
# seaborn: 0.10.0

# %%
X = np.random.normal(size=1000)

# %%
sns.lineplot(y=X, x=range(len(X)))
plt.grid()
plt.tight_layout()
plt.show();
